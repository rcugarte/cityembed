# %% [markdown]
# <a href="https://colab.research.google.com/github/rcugarte/cityembed/blob/main/visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CityEmbed Visualizations
#
# See the full GitHub repository [here](https://github.com/rcugarte/cityembed).

# %% [markdown]
# ### Data Preparation

# %%
# !pip install pandas ast numpy plotly umap-learn matplotlib
import pandas as pd
import ast
import numpy as np
import plotly.graph_objs as go
import plotly.io as pio
import umap.umap_ as umap
import matplotlib.pyplot as plt
import plotly.colors as pc
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.5.3)
# Collecting ast
#   Using cached AST-0.0.2.tar.gz (19 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
url = 'https://raw.githubusercontent.com/rcugarte/cityembed/master/city_embedding_data.csv'
cities = pd.read_csv(url)

# %%
cities
# Out:
#      Unnamed: 0                          city                      country  \
# 0             0       Aachen-Liège-Maastricht  Germany Belgium Netherlands
# 1             1  Abbotsford, British Columbia                       Canada
# 2             2                      Aberdeen               United Kingdom
# 3             3                       Abidjan                  Ivory Coast
# 4             4                     Abu Dhabi         United Arab Emirates
# ..          ...                           ...                          ...
# 446         446                     Zhengzhou                        China
# 447         447                     Zhongshan                        China
# 448         448                        Zhuhai                        China
# 449         449                          Zibo                        China
# 450         450                        Zürich                  Switzerland
#
#               region     gdp_pc  \
# 0     Western Europe  28,493.71
# 1      North America  30,321.44
# 2    Northern Europe  46,957.94
# 3             Africa   4,537.82
# 4       Western Asia  71,686.75
# ..               ...        ...
# 446     Eastern Asia  16,089.39
# 447     Eastern Asia  11,566.16
# 448     Eastern Asia  16,344.09
# 449     Eastern Asia  19,006.71
# 450   Western Europe  74,193.88
#
#                                          wikipedia_url  \
# 0                 https://en.wikipedia.org/wiki/Aachen
# 1    https://en.wikipedia.org/wiki/Abbotsford,_Brit...
# 2               https://en.wikipedia.org/wiki/Aberdeen
# 3                https://en.wikipedia.org/wiki/Abidjan
# 4              https://en.wikipedia.org/wiki/Abu_Dhabi
# ..                                                 ...
# 446            https://en.wikipedia.org/wiki/Zhengzhou
# 447            https://en.wikipedia.org/wiki/Zhongshan
# 448               https://en.wikipedia.org/wiki/Zhuhai
# 449                 https://en.wikipedia.org/wiki/Zibo
# 450          https://en.wikipedia.org/wiki/Z%C3%BCrich
#
#                                        wikipedia_intro  \
# 0    Aachen (/ˈɑːxən/ AH-khən; German: [ˈaːxn̩] (li...
# 1    Abbotsford is a city located in British Columb...
# 2    Aberdeen (/ˌæbərˈdiːn/ (listen); Scots: Aiberd...
# 3    Abidjan (/ˌæbɪˈdʒɑːn/ AB-ih-JAHN, French: [abi...
# 4    Abu Dhabi (UK: /ˈæbuːˈdæbi/, US: /ˈɑːbuːˈdɑːbi...
# ..                                                 ...
# 446  Zhengzhou (/dʒɛŋˈdʒoʊ, dʒʌŋ-/;[3] simplified C...
# 447  Zhongshan ([ʈʂʊ́ŋ ʂán]; Chinese: 中山) is a pre...
# 448  Zhuhai (/ˈdʒuːˈhaɪ/,[3] Chinese: 珠海; pinyin: Z...
# 449  Zibo (Chinese: 淄博, tsee-PWOH) is a prefecture-...
# 450  Zürich (/ˈzjʊərɪk, ˈzʊərɪk/ ZURE-ik, ZOOR-ik, ...
#
#                                              embedding
# 0    [0.025970444083213806, 0.010382960550487041, 0...
# 1    [0.002416889648884535, -0.01665973663330078, -...
# 2    [0.008810719475150108, -0.020789921283721924, ...
# 3    [-0.01380961760878563, -0.01290480513125658, 0...
# 4    [-0.006597555708140135, -0.014655590988695621,...
# ..                                                 ...
# 446  [0.0016842980403453112, -0.023999657481908798,...
# 447  [0.0200781412422657, -0.00019213088671676815, ...
# 448  [0.0067623937502503395, -0.011905440129339695,...
# 449  [-0.015531720593571663, -0.024248503148555756,...
# 450  [-0.0015587260713800788, -0.00541544146835804,...
#
# [451 rows x 8 columns]

# %%
# formatting embeddings appropriately
cities['embedding'] = cities['embedding'].apply(lambda x: ast.literal_eval(x))

# %% [markdown]
# ### Global PCA Visualization

# %%
# load the embeddings and names from the dataframe
embeddings = np.array(cities['embedding'].tolist())
names = np.array(cities['city'].tolist())

# %%
# perform PCA on the embeddings
pca_result = PCA(n_components=2).fit_transform(embeddings)

# map categories to integer codes
cat_codes, cat_names = pd.factorize(cities['region'])

# map categories to colors
colors = px.colors.qualitative.Plotly
color_dict = {i % len(colors): colors[i % len(colors)] for i in range(len(cat_names))}
    
# create a scatter plot of the PCA results
scatter = go.Scatter(
    x=pca_result[:, 0],
    y=pca_result[:, 1],
    mode='markers',
    marker=dict(
        size=5,
        sizemode='diameter',
        color=pd.Series(cat_codes).map(color_dict),
        opacity=0.8,
        showscale=False
    ),
    text=names,
    hoverinfo='text',
    showlegend=False
)

# set plot title and axis labels
layout = go.Layout(
    title="PCA City Embeddings Visualization (Global)",
    xaxis=dict(title="PCA Component 1"),
    yaxis=dict(title="PCA Component 2"),
    hovermode='closest',
    legend=dict(title='Region')
)

# create the figure
fig = go.Figure(data=[scatter], layout=layout)

# add legend with discrete colors and labels
for code, name in enumerate(cat_names):
    fig.add_trace(go.Scatter(x=[None], y=[None], mode='markers', marker=dict(size=10, color=color_dict[code % len(colors)]), showlegend=True, name=name))

# show the plot
pio.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7ae78435-baba-411b-a0d9-bc8c02a0888e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ae78435-baba-411b-a0d9-bc8c02a0888e")) {                    Plotly.newPlot(                        "7ae78435-baba-411b-a0d9-bc8c02a0888e",                        [{"hoverinfo":"text","marker":{"color":["#636EFA","#EF553B","#00CC96","#AB63FA","#FFA15A","#19D3F3","#FF6692","#EF553B","#EF553B","#EF553B","#AB63FA","#EF553B","#B6E880","#636EFA","#FF97FF","#FFA15A","#FECB52","#636EFA",null,"#EF553B","#19D3F3","#EF553B","#EF553B","#19D3F3","#EF553B",null,null,null,"#FECB52",null,"#EF553B","#636EFA","#EF553B","#FECB52","#00CC96",null,"#EF553B","#FF97FF","#19D3F3","#FF6692","#636EFA","#FF6692","#636EFA",null,"#00CC96","#EF553B","#FF97FF",null,"#636EFA","#EF553B","#EF553B","#FF97FF","#636EFA","#636EFA","#EF553B","#19D3F3","#00CC96","#636EFA",null,null,"#FF97FF","#EF553B","#FFA15A","#FECB52","#19D3F3","#AB63FA","#EF553B","#FF97FF","#FF97FF","#FF97FF","#19D3F3","#AB63FA","#FF97FF","#00CC96","#AB63FA","#FF6692","#FECB52","#FECB52","#FECB52","#EF553B","#EF553B","#FECB52","#FF6692","#FF6692","#EF553B","#FF6692","#FECB52","#EF553B","#EF553B",null,"#EF553B","#EF553B","#00CC96","#00CC96","#00CC96","#FF97FF","#FECB52","#FECB52","#FECB52","#EF553B","#AB63FA","#FECB52","#EF553B","#FF6692","#EF553B","#EF553B","#EF553B","#FF6692","#FECB52","#FECB52","#FFA15A","#00CC96","#AB63FA","#EF553B","#AB63FA","#00CC96","#EF553B","#636EFA","#EF553B","#FF6692",null,"#FF97FF","#FECB52","#636EFA","#EF553B","#FECB52","#FECB52","#19D3F3","#636EFA",null,null,"#19D3F3","#00CC96","#00CC96","#19D3F3","#EF553B","#EF553B","#EF553B","#FF97FF","#EF553B","#FECB52","#EF553B","#FF6692","#FECB52","#FFA15A","#EF553B","#FECB52","#636EFA","#EF553B","#FECB52","#636EFA",null,"#FECB52","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#FECB52","#00CC96","#FECB52","#19D3F3",null,"#FECB52","#EF553B","#EF553B","#FECB52","#FECB52","#EF553B","#FF6692","#EF553B","#FF6692","#FFA15A","#FFA15A","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#FF6692",null,"#FFA15A","#FFA15A","#FECB52","#AB63FA","#FF97FF","#FF6692","#FECB52","#EF553B","#FECB52","#FF6692","#636EFA",null,"#00CC96","#EF553B",null,"#EF553B","#EF553B","#00CC96","#EF553B","#FF6692",null,null,"#FECB52","#FECB52","#FFA15A","#AB63FA","#FF6692","#19D3F3","#EF553B","#00CC96","#636EFA","#EF553B","#636EFA","#FF97FF",null,null,"#EF553B","#00CC96","#00CC96","#EF553B","#EF553B","#EF553B","#FF6692","#636EFA","#636EFA","#FECB52","#19D3F3","#EF553B",null,null,"#FF97FF","#00CC96",null,"#636EFA","#FF97FF",null,"#19D3F3","#EF553B","#EF553B","#EF553B",null,"#EF553B","#EF553B",null,"#636EFA","#EF553B","#EF553B","#FF97FF","#EF553B",null,"#FF6692","#FF6692","#636EFA","#FECB52","#FF6692","#AB63FA","#FECB52","#FECB52","#FECB52","#636EFA","#FECB52",null,"#EF553B","#EF553B","#EF553B","#EF553B","#19D3F3","#636EFA","#636EFA","#FECB52","#FECB52","#EF553B","#636EFA","#FECB52","#EF553B","#EF553B","#19D3F3","#EF553B","#FECB52","#EF553B","#00CC96","#EF553B","#EF553B",null,"#636EFA","#FF6692","#19D3F3","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B",null,"#FF97FF",null,"#AB63FA","#EF553B","#EF553B","#FF6692","#FECB52","#EF553B","#EF553B","#FF97FF","#EF553B","#636EFA","#EF553B","#00CC96","#FF97FF","#EF553B","#FFA15A","#EF553B","#19D3F3",null,"#636EFA","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#00CC96","#FF97FF","#EF553B","#EF553B","#EF553B","#EF553B",null,null,"#FF97FF ...

# %% [markdown]
# ### Global t-SNE Visualization

# %%
# perform t-SNE on the embeddings
tsne_result = TSNE(n_components=2, perplexity=30, metric='euclidean').fit_transform(embeddings)
    
# map categories to integer codes
cat_codes, cat_names = pd.factorize(cities['region'])

# map categories to colors
colors = px.colors.qualitative.Plotly
color_dict = {i % len(colors): colors[i % len(colors)] for i in range(len(cat_names))}
    
# create a scatter plot of the t-SNE results
scatter = go.Scatter(
    x=tsne_result[:, 0],
    y=tsne_result[:, 1],
    mode='markers',
    marker=dict(
        size=5,
        sizemode='diameter',
        color=pd.Series(cat_codes).map(color_dict),
        opacity=0.8,
        showscale=False
    ),
    text=names,
    hoverinfo='text',
    showlegend=False
)

# set plot title and axis labels
layout = go.Layout(
    title="t-SNE City Embeddings Visualization (Global)",
553B","#EF553B",null,"#EF553B","#EF553B",null,"#636EFA","#EF553B","#EF553B","#FF97FF","#EF553B",null,"#FF6692","#FF6692","#636EFA","#FECB52","#FF6692","#AB63FA","#FECB52","#FECB52","#FECB52","#636EFA","#FECB52",null,"#EF553B","#EF553B","#EF553B","#EF553B","#19D3F3","#636EFA","#636EFA","#FECB52","#FECB52","#EF553B","#636EFA","#FECB52","#EF553B","#EF553B","#19D3F3","#EF553B","#FECB52","#EF553B","#00CC96","#EF553B","#EF553B",null,"#636EFA","#FF6692","#19D3F3","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B",null,"#FF97FF",null,"#AB63FA","#EF553B","#EF553B","#FF6692","#FECB52","#EF553B","#EF553B","#FF97FF","#EF553B","#636EFA","#EF553B","#00CC96","#FF97FF","#EF553B","#FFA15A","#EF553B","#19D3F3",null,"#636EFA","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#00CC96","#FF97FF","#EF553B","#EF553B","#EF553B","#EF553B",null,null,"#FF97FF ...

# %% [markdown]
# ### Global UMAP Visualization

# %%
# perform UMAP on the embeddings
umap_result = umap.UMAP(n_neighbors=15, min_dist=0.1, metric='euclidean').fit_transform(embeddings)
    
# map categories to integer codes
cat_codes, cat_names = pd.factorize(cities['region'])

# map categories to colors
colors = px.colors.qualitative.Plotly
color_dict = {i % len(colors): colors[i % len(colors)] for i in range(len(cat_names))}
    
# create a scatter plot of the UMAP results
scatter = go.Scatter(
    x=umap_result[:, 0],
    y=umap_result[:, 1],
    mode='markers',
    marker=dict(
        size=5,
        sizemode='diameter',
        color=pd.Series(cat_codes).map(color_dict),
        opacity=0.8,
        showscale=False
    ),
    text=names,
    hoverinfo='text',
    showlegend=False
)

# set plot title and axis labels
layout = go.Layout(
    title="UMAP City Embeddings Visualization (Global)",
    xaxis=dict(title="UMAP Component 1"),
    yaxis=dict(title="UMAP Component 2"),
    hovermode='closest',
    legend=dict(title='Region')
)

# create the figure
fig = go.Figure(data=[scatter], layout=layout)

# add legend with discrete colors and labels
for code, name in enumerate(cat_names):
    fig.add_trace(go.Scatter(x=[None], y=[None], mode='markers', marker=dict(size=10, color=color_dict[code % len(colors)]), showlegend=True, name=name))

# show the plot
pio.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d4e58596-0a60-45c5-aa70-f2882fc7907a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4e58596-0a60-45c5-aa70-f2882fc7907a")) {                    Plotly.newPlot(                        "d4e58596-0a60-45c5-aa70-f2882fc7907a",                        [{"hoverinfo":"text","marker":{"color":["#636EFA","#EF553B","#00CC96","#AB63FA","#FFA15A","#19D3F3","#FF6692","#EF553B","#EF553B","#EF553B","#AB63FA","#EF553B","#B6E880","#636EFA","#FF97FF","#FFA15A","#FECB52","#636EFA",null,"#EF553B","#19D3F3","#EF553B","#EF553B","#19D3F3","#EF553B",null,null,null,"#FECB52",null,"#EF553B","#636EFA","#EF553B","#FECB52","#00CC96",null,"#EF553B","#FF97FF","#19D3F3","#FF6692","#636EFA","#FF6692","#636EFA",null,"#00CC96","#EF553B","#FF97FF",null,"#636EFA","#EF553B","#EF553B","#FF97FF","#636EFA","#636EFA","#EF553B","#19D3F3","#00CC96","#636EFA",null,null,"#FF97FF","#EF553B","#FFA15A","#FECB52","#19D3F3","#AB63FA","#EF553B","#FF97FF","#FF97FF","#FF97FF","#19D3F3","#AB63FA","#FF97FF","#00CC96","#AB63FA","#FF6692","#FECB52","#FECB52","#FECB52","#EF553B","#EF553B","#FECB52","#FF6692","#FF6692","#EF553B","
# 433         433           Wichita  United States  North America  62,646.72
# 437         437         Worcester  United States  North America  56,150.21
#
#                                          wikipedia_url  \
# 7                  https://en.wikipedia.org/wiki/Akron
# 8       https://en.wikipedia.org/wiki/Albany,_New_York
# 9            https://en.wikipedia.org/wiki/Albuquerque
# 11   https://en.wikipedia.org/wiki/Allentown,_Penns...
# 19               https://en.wikipedia.org/wiki/Atlanta
# ..                                                 ...
# 416                https://en.wikipedia.org/wiki/Tulsa
# 426  https://en.wikipedia.org/wiki/Virginia_Beach,_...
# 431     https://en.wikipedia.org/wiki/Washington,_D.C.
# 433      https://en.wikipedia.org/wiki/Wichita,_Kansas
# 437  https://en.wikipedia.org/wiki/Worcester,_Massa...
#
#                                        wikipedia_intro  \
# 7    Akron (/ˈækrən/) is the fifth-largest city in ...
# 8    Albany (/ˈɔːlbəni/ (listen) AWL-bən-ee) is the...
# 9    Albuquerque (/ˈælbəˌkɜːrki/ (listen) AL-bə-kur...
# 11   Allentown (Pennsylvania Dutch: Allenschteddel,...
# 19   Atlanta (/ætˈlæntə/ at-LAN-tə) is the capital ...
# ..                                                 ...
# 416  Tulsa (/ˈtʌlsə/) is the second-largest city in...
# 426  Virginia Beach is an independent city located ...
# 431  Washington, D.C., formally the District of Col...
# 433  Wichita (/ˈwɪtʃɪtɔː/ WITCH-ih-taw)[10] is the ...
# 437  Worcester (/ˈwʊstər/ (listen) WUUS-tər, locall...
#
#                                              embedding
# 7    [0.013709683902561665, -0.0066631874069571495,...
# 8    [0.02120584063231945, -0.0038955307099968195, ...
# 9    [-0.01403997652232647, 0.0021814152132719755, ...
# 11   [-0.009336583316326141, 0.000967484200373292, ...
# 19   [-0.01681656762957573, -0.0009408590267412364,...
# ..                                                 ...
# 416  [-0.01718195527791977, -0.01315036416053772, 0...
# 426  [-0.025677744299173355, -0.029091402888298035,...
# 431  [-0.00948111992329359, 0.004734338726848364, -...
# 433  [-0.014312542043626308, -0.006363625638186932,...
# 437  [0.012153456918895245, 0.00966854952275753, -0...
#
# [121 rows x 8 columns]

# %%
# load the embeddings and names from the dataframe
us_embeddings = np.array(us_cities['embedding'].tolist())
us_names = np.array(us_cities['city'].tolist())

# %%
# perform UMAP on the embeddings
umap_result = umap.UMAP(n_neighbors=5, min_dist=0.1, metric='euclidean').fit_transform(us_embeddings)

# create a scatter plot of the UMAP results
scatter = go.Scatter(
    x=umap_result[:, 0],
    y=umap_result[:, 1],
    mode='markers',
    marker=dict(
        size=5,
        sizemode='diameter',
        color='red',
        opacity=0.8,
        showscale=False
    ),
    text=us_names,
    hoverinfo='text',
    showlegend=False
)

# set plot title and axis labels
layout = go.Layout(
    title="UMAP City Embeddings Visualization (United States)",
    xaxis=dict(title="UMAP Component 1"),
    yaxis=dict(title="UMAP Component 2"),
    hovermode='closest',
    legend=dict(title='Region')
)

# create the figure
fig = go.Figure(data=[scatter], layout=layout)

# show the plot
pio.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="31bec4b3-9a61-4fef-a221-4a4abb04743b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("